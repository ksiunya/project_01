# %%
# Зарплата сотрудника составляет salary руб., 
# Расходы на проживание превышают зараплату и составляют expenses руб. в месяц. 
# Рост цен ежемесячно увеличивает расходы на 3%, кроме первого месяца
# Напишите скрипт расчета суммы денег, которую необходимо взять в долг, 
# чтобы можно было прожить ближайший год (12 месяцев).
# Формат вывода:
# Необходимо взять в долг ХХХ.ХХ рублей

salary, expenses = 10000, 12000

my_expenses = list()
my_expenses.append(expenses)

for i in range(11):
 my_expenses.append(round(my_expenses[i]*1.03,2))
print(my_expenses)

total_expenses = round(sum(my_expenses),2)
print(total_expenses)

print('Необходимо взять в долг', round(total_expenses - salary*12,2), 'рублей')
# Out:
# [12000, 12360.0, 12730.8, 13112.72, 13506.1, 13911.28, 14328.62, 14758.48, 15201.23, 15657.27, 16126.99, 16610.8]
# 170304.29
# Необходимо взять в долг 50304.29 рублей
